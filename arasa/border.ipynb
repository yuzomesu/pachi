# %%
import numpy as np

# %%
furiwake = np.array([0.125,0.04025,0.000875,0.4375,0.396375])
rounds = np.array([2,2,10,7,7])
alpha = 40/2.9

# %%
# Lt
iter = 1/(1-108/137)-1
p = 1/2.9
furiwake_LT = np.array([p ** 5, p ** 4 * (1 - p) * 5, p ** 3 * (1 - p) ** 2 * 10, p ** 2 * (1 - p) ** 3 * 10, p * (1 - p) ** 4 * 5, (1 - p) ** 5])
dedama = np.array([60,40,30,20,10,0])
print(np.dot(dedama,furiwake_LT))
# Out:
# 17.290133283123243

# %%
EX_total = np.dot(furiwake, rounds) + (iter * (np.dot(dedama,furiwake_LT) + p ** 5 * alpha)) * (furiwake[1] + furiwake[2] + furiwake[3])
EX_total
# Out:
# np.float64(37.115306572993354)

# %%
# border
349.9/EX_total*250
# Out:
# np.float64(2356.8443339667965)

# %%
2353.424123723487/139
# Out:
# 16.931108803766094
