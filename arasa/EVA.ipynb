# %%
# モジュール
import numpy as np
import random
import sys
from tqdm import tqdm
import matplotlib.pyplot as plt
sys.setrecursionlimit(100000000)

# %%
# スペック部分
class spec:
    #通常2000回転やって収支を出す
    def __init__(self,a,b,c,d,e):
        self.kaitensuu = a #現在の累計回転数
        self.all = b # 累計回転
        self.balls = c # 現在の出玉
        self.border = d # 1kあたりの回転
        self.limit = e

    def normal(self):
        limit = self.limit #回転数上限
        cost = 250 / self.border # 1回転あたりのコスト
        while True:
            if self.all > limit:
                return self.balls
            x = random.random()
            self.kaitensuu += 1
            self.balls -= cost
            self.all += 1

            if x <= 1/319.7*0.03:
                self.kaitensuu = 0
                self.balls += 1400
                self.rush()
            elif x <= 1/319.7 * 0.59:
                self.kaitensuu = 0
                self.balls += 420
                self.rush()
            elif x <= 1/319.7:
                self.kaitensuu = 0
                self.balls += 420
                self.short()
    def rush(self):
        x = random.random()
        if x <= 0.809989:
            self.balls += 1400
            self.rush()
        else:
            self.normal()

    def short(self):
        x = np.random.geometric(1/319.9)
        if x <= 104:
            self.balls += 1400
            self.rush()
        else:
            self.normal()

# %%
instance = spec(0, 0, 0, 18, 1000000) # 初期化
balls = instance.normal()
balls
# Out:
# 1193157.2222324365

# %%
result2 = []
for i in tqdm(range(100000)):
    instance = spec(0, 0, 0, 17, 10000) # 初期化
    balls = instance.normal()
    result2.append(balls)

print("平均収支: ", np.mean(result2))
print("標準偏差: ", np.std(result2))
print("最大値: ", np.max(result2))
print("最小値: ", np.min(result2))
print("5%点: ", np.percentile(result2, 5))
print("95%点: ", np.percentile(result2, 95))
plt.hist(np.array(result2), bins=50, edgecolor='black', alpha=0.7)
plt.show()
# Out:
#   4%|▎         | 3533/100000 [00:03<01:28, 1095.68it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 for i in tqdm(range(100000)):
#       3     instance = spec(0, 0, 0, 17, 10000) # 初期化
# ----> 4     balls = instance.normal()
#       5     result2.append(balls)
#       7 print("平均収支: ", np.mean(result2))
#
# Cell In[2], line 25, in spec.normal(self)
#      23     self.kaitensuu = 0
#      24     self.balls += 1400
# ---> 25     self.rush()
#      26 elif x <= 1/319.7 * 0.59:
#      27     self.kaitensuu = 0
#
# Cell In[2], line 38, in spec.rush(self)
#      36 if x <= 0.809989:
#      37     self.balls += 1400
# ---> 38     self.rush()
#      39 else:
#      40     self.normal()
#
# Cell In[2], line 40, in spec.rush(self)
#      38     self.rush()
#      39 else:
# ---> 40     self.normal()
#
# Cell In[2], line 29, in spec.normal(self)
# ...

# %%
import scipy.stats as stats
from scipy.stats import percentileofscore
result2 = sorted(result2)
print(np.percentile(result2, 17))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import scipy.stats as stats
#       2 from scipy.stats import percentileofscore
#       3 result2 = sorted(result2)
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/site-packages/scipy/stats/__init__.py:610
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     605
#     606 """  # noqa: E501
#     608 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     609                                DegenerateDataWarning, FitError)
# --> 610 from ._stats_py import *
#     611 from ._variation import variation
#     612 from .distributions import *
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/site-packages/scipy/stats/_stats_py.py:49
#      46 # Import unused here but needs to stay until end of deprecation periode
# ...

# %%
result2 = np.array(result2)/2


print("平均収支: ", np.mean(result2))
print("標準偏差: ", np.std(result2))
print("最大値: ", np.max(result2))
print("最小値: ", np.min(result2))
print("5%点: ", np.percentile(result2, 5))
print("95%点: ", np.percentile(result2, 95))
plt.hist(np.array(result2), bins=50, edgecolor='black', alpha=0.7)
plt.show()
# Out:
# 平均収支:  654.7583529413379
# 標準偏差:  13922.309506565956
# 最大値:  88110.88235293445
# 最小値:  -29419.117647060968
# 5%点:  -19059.117647059356
# 95%点:  26160.882352939705

# %%
result = []
for i in tqdm(range(10000)):
    instance = spec(0, 0, 0, 19, 30000) # 初期化
    balls = instance.normal()
    result.append(balls)
# Out:
# 100%|██████████| 10000/10000 [00:28<00:00, 349.37it/s]

# %%
print("平均収支: ", np.mean(result))
print("標準偏差: ", np.std(result))
print("最大値: ", np.max(result))
print("最小値: ", np.min(result))
print("5%点: ", np.percentile(result, 5))
print("95%点: ", np.percentile(result, 95))
plt.hist(np.array(result), bins=50, edgecolor='black', alpha=0.7)
plt.show()
# Out:
# 平均収支:  57707.58600000313
# 標準偏差:  75743.81872950801
# 最大値:  395409.9999997727
# 最小値:  -175650.0000000652
# 5%点:  -60149.99999996247
# 95%点:  189049.99999982753

# %%
result = []
for i in tqdm(range(100000)):
    instance = spec(0, 0, 0, 17, 6000) # 初期化
    balls = instance.normal()
    result.append(balls/2)
# Out:
# 100%|██████████| 100000/100000 [00:55<00:00, 1805.80it/s]

# %%
print("平均収支: ", np.mean(result))
print("標準偏差: ", np.std(result))
print("最大値: ", np.max(result))
print("最小値: ", np.min(result))
print("5%点: ", np.percentile(result, 5))
print("95%点: ", np.percentile(result, 95))
plt.hist(np.array(result), bins=50, edgecolor='black', alpha=0.7)
plt.show()
# Out:
# 平均収支:  1093.4550999998885
# 標準偏差:  17174.299485693322
# 最大値:  103784.99999999904
# 最小値:  -42445.00000000015
# 5%点:  -23965.000000001623
# 95%点:  31964.999999999276
